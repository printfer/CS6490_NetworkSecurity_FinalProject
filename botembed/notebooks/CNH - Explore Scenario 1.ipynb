# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from scipy.special import softmax

# %%
# import scenario 1 (CTU-42)
dsn = pd.read_csv('../data/scenario_1.csv')

# %%
dsn['Label'].unique()
# Out:
# array(['flow=Background-UDP-Established', 'flow=Background',
#        'flow=Background-Established-cmpgw-CVUT',
#        'flow=Background-TCP-Established',
#        'flow=From-Background-CVUT-Proxy',
#        'flow=To-Background-UDP-CVUT-DNS-Server',
#        'flow=Background-UDP-Attempt',
#        'flow=From-Normal-V42-UDP-CVUT-DNS-Server',
#        'flow=Background-UDP-NTP-Established-1',
#        'flow=To-Background-CVUT-WebServer',
#        'flow=Background-google-analytics3',
#        'flow=Background-Attempt-cmpgw-CVUT',
#        'flow=To-Background-CVUT-Proxy',
#        'flow=Background-google-analytics2',
#        'flow=Background-google-analytics6', 'flow=From-Normal-V42-Jist',
#        'flow=Background-google-webmail', 'flow=Background-TCP-Attempt',
#        'flow=Background-google-analytics12',
#        'flow=Background-google-analytics1',
#        'flow=Background-google-analytics13',
#        'flow=Background-google-analytics14', 'flow=To-Background-Jist',
#        'flow=Background-ajax.google', 'flow=From-Normal-V42-Grill',
#        'flow=Background-google-analytics9',
#        'flow=Background-google-analytics11', 'flow=Background-google-pop',
#        'flow=From-Normal-V42-Stribrek',
#        'flow=To-Normal-V42-UDP-NTP-server',
#        'flow=Background-google-analytics16',
#        'flow=Background-google-analytics4', 'flow=To-Background-Stribrek',
#        'flow=Background-google-analytics10',
#        'flow=Background-google-analytics5',
#        'flow=Background-google-analytics15', 'flow=To-Background-Grill',
#        'flow=From-Normal-V42-CVUT-WebServer',
#        'flow=To-Background-MatLab-Server',
#        'flow=Background-google-analytics8',
#        'flow=Background-google-analytics7',
#        'flow=Background-www.fel.cvut.cz',
#        'flow=Normal-V42-HTTP-windowsupdate',
#        'flow=From-Normal-V42-MatLab-Server',
#        'flow=From-Botnet-V42-UDP-DNS',
#        'flow=From-Botnet-V42-TCP-HTTP-Google-Net-Established-6',
#        'flow=From-Botnet-V42-TCP-Established',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Binary-Download-1',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Binary-Download-Custom-Port-7',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Binary-Download-3',
#        'flow=From-Botnet-V42-TCP-CC6-Plain-HTTP-Encrypted-Data',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Binary-Download-Custom-Port-4',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-63',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Binary-Download-9',
#        'flow=From-Botnet-V42-TCP-WEB-Established',
#        'flow=From-Botnet-V42-TCP-Attempt',
#        'flow=From-Botnet-V42-TCP-CC54-Custom-Encryption',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-64',
#        'flow=From-Botnet-V42-TCP-CC53-HTTP-Not-Encrypted',
#        'flow=From-Botnet-V42-TCP-Attempt-SPAM',
#        'flow=From-Botnet-V42-TCP-CC1-HTTP-Not-Encrypted',
#        'flow=From-Botnet-V42-TCP-Not-Encrypted-SMTP-Private-Proxy-1',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-40',
#        'flow=From-Botnet-V42-UDP-Established',
#        'flow=From-Botnet-V42-TCP-CC16-HTTP-Not-Encrypted',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-15',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-44',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-16',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Adobe-4',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-18',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-20',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-37',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-59',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-25',
#        'flow=From-Botnet-V42-TCP-Established-SPAM',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-1',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-yieldmanager-9',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Binary-Download-Custom-Port-5',
#        'flow=From-Botnet-V42-TCP-HTTP-Not-Encrypted-Down-2',
#        'flow=From-Botnet-V42-TCP-CC55-Custom-Encryption',
#        'flow=From-Botnet-V42-TCP-WEB-Established-SSL',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-12',
#        'flow=From-Botnet-V42-TCP-Established-Custom-Encryption-3',
#        'flow=From-Botnet-V42-TCP-Established-Custom-Encryption-2',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-21',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-55',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-5',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-53',
#        'flow=From-Botnet-V42-TCP-Established-SSL-To-Microsoft-4',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-47',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-30',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-10',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-6',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-51',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-32',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-3',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-57',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-60',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-41',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-61',
#        'flow=From-Botnet-V42-ICMP',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-48',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-28',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-42',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-50',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-7',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-33',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-45',
#        'flow=From-Botnet-V42-UDP-Attempt-DNS',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-52',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-49',
#        'flow=From-Botnet-V42-TCP-Established-HTTP-Ad-34',
#        'flow=Background-CS-Host-CVUT'], dtype=object)

# %%
pd.options.display.max_rows=150
dsn.groupby('Label').count()['SrcAddr']
# Out:
# Label
# flow=Background                                                              40216
# flow=Background-Attempt-cmpgw-CVUT                                           30983
# flow=Background-CS-Host-CVUT                                                    22
# flow=Background-Established-cmpgw-CVUT                                      137257
# flow=Background-TCP-Attempt                                                 105438
# flow=Background-TCP-Established                                             223543
# flow=Background-UDP-Attempt                                                  66699
# flow=Background-UDP-Established                                            1169677
# flow=Background-UDP-NTP-Established-1                                         2233
# flow=Background-ajax.google                                                   1197
# flow=Background-google-analytics1                                              500
# flow=Background-google-analytics10                                             732
# flow=Background-google-analytics11                                             529
# flow=Background-google-analytics12                                             542
# flow=Background-google-analytics13                                             595
# flow=Background-google-analytics14                                             538
# flow=Background-google-analytics15                                             536
# flow=Background-google-analytics16                                             599
# flow=Background-google-analytics2                                              522
# flow=Background-google-analytics3                                              579
# flow=Background-google-analytics4                                              569
# flow=Background-google-analytics5                                              505
# flow=Background-google-analytics6                                              628
# flow=Background-google-analytics7                                              624
# flow=Background-google-analytics8                                              630
# flow=Background-google-analytics9                                              561
# flow=Background-google-pop                                                     407
# flow=Background-google-webmail                                                 560
# flow=Background-www.fel.cvut.cz                                                310
# flow=From-Background-CVUT-Proxy                                                502
# flow=From-Botnet-V42-ICMP                                                        2
# flow=From-Botnet-V42-TCP-Attempt                                              1881
# flow=From-Botnet-V42-TCP-Attempt-SPAM                                         8105
# flow=From-Botnet-V42-TCP-CC1-HTTP-Not-Encrypted                                 37
# flow=From-Botnet-V42-TCP-CC16-HTTP-Not-Encrypted                               221
# flow=From-Botnet-V42-TCP-CC53-HTTP-Not-Encrypted                                53
# flow=From-Botnet-V42-TCP-CC54-Custom-Encryption                                 11
# flow=From-Botnet-V42-TCP-CC55-Custom-Encryption                                  9
# flow=From-Botnet-V42-TCP-CC6-Plain-HTTP-Encrypted-Data                          10
# flow=From-Botnet-V42-TCP-Established                                            43
# flow=From-Botnet-V42-TCP-Established-Custom-Encryption-2                         5
# flow=From-Botnet-V42-TCP-Established-Custom-Encryption-3                         5
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-1                                  38
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-10                                 13
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-12                                  4
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-15                                 29
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-16                                 16
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-18                                 31
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-20                                 32
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-21                                 31
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-25                                  7
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-28                                  3
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-3                                  14
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-30                                 21
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-32                                 14
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-33                                  3
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-34                                  2
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-37                                 21
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-40                                 15
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-41                                  9
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-42                                  3
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-44                                 23
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-45                                  8
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-47                                  3
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-48                                  7
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-49                                  1
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-5                                   3
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-50                                  4
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-51                                  4
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-52                                  4
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-53                                  3
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-55                                 28
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-57                                  3
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-59                                  4
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-6                                   6
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-60                                  1
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-61                                 13
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-63                                352
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-64                                  2
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-7                                   9
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-yieldmanager-9                     26
# flow=From-Botnet-V42-TCP-Established-HTTP-Adobe-4                                1
# flow=From-Botnet-V42-TCP-Established-HTTP-Binary-Download-1                      3
# flow=From-Botnet-V42-TCP-Established-HTTP-Binary-Download-3                      6
# flow=From-Botnet-V42-TCP-Established-HTTP-Binary-Download-9                      2
# flow=From-Botnet-V42-TCP-Established-HTTP-Binary-Download-Custom-Port-4          2
# flow=From-Botnet-V42-TCP-Established-HTTP-Binary-Download-Custom-Port-5          1
# flow=From-Botnet-V42-TCP-Established-HTTP-Binary-Download-Custom-Port-7          2
# flow=From-Botnet-V42-TCP-Established-SPAM                                       62
# flow=From-Botnet-V42-TCP-Established-SSL-To-Microsoft-4                         13
# flow=From-Botnet-V42-TCP-HTTP-Google-Net-Established-6                          10
# flow=From-Botnet-V42-TCP-HTTP-Not-Encrypted-Down-2                               1
# flow=From-Botnet-V42-TCP-Not-Encrypted-SMTP-Private-Proxy-1                    320
# flow=From-Botnet-V42-TCP-WEB-Established                                        93
# flow=From-Botnet-V42-TCP-WEB-Established-SSL                                    50
# flow=From-Botnet-V42-UDP-Attempt-DNS                                          3057
# flow=From-Botnet-V42-UDP-DNS                                                 26140
# flow=From-Botnet-V42-UDP-Established                                             6
# flow=From-Normal-V42-CVUT-WebServer                                            269
# flow=From-Normal-V42-Grill                                                    7654
# flow=From-Normal-V42-Jist                                                     3808
# flow=From-Normal-V42-MatLab-Server                                               6
# flow=From-Normal-V42-Stribrek                                                18438
# flow=From-Normal-V42-UDP-CVUT-DNS-Server                                        83
# flow=Normal-V42-HTTP-windowsupdate                                               9
# flow=To-Background-CVUT-Proxy                                                19542
# flow=To-Background-CVUT-WebServer                                             2587
# flow=To-Background-Grill                                                       294
# flow=To-Background-Jist                                                         60
# flow=To-Background-MatLab-Server                                               833
# flow=To-Background-Stribrek                                                     33
# flow=To-Background-UDP-CVUT-DNS-Server                                      941706
# flow=To-Normal-V42-UDP-NTP-server                                              120
# Name: SrcAddr, dtype: int64

# %%
# Unique Botnet Labels
for label in dsn['Label'].unique():
    if 'botnet' in label.lower():
        print(label)
# Out:
# flow=From-Botnet-V42-UDP-DNS
# flow=From-Botnet-V42-TCP-HTTP-Google-Net-Established-6
# flow=From-Botnet-V42-TCP-Established
# flow=From-Botnet-V42-TCP-Established-HTTP-Binary-Download-1
# flow=From-Botnet-V42-TCP-Established-HTTP-Binary-Download-Custom-Port-7
# flow=From-Botnet-V42-TCP-Established-HTTP-Binary-Download-3
# flow=From-Botnet-V42-TCP-CC6-Plain-HTTP-Encrypted-Data
# flow=From-Botnet-V42-TCP-Established-HTTP-Binary-Download-Custom-Port-4
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-63
# flow=From-Botnet-V42-TCP-Established-HTTP-Binary-Download-9
# flow=From-Botnet-V42-TCP-WEB-Established
# flow=From-Botnet-V42-TCP-Attempt
# flow=From-Botnet-V42-TCP-CC54-Custom-Encryption
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-64
# flow=From-Botnet-V42-TCP-CC53-HTTP-Not-Encrypted
# flow=From-Botnet-V42-TCP-Attempt-SPAM
# flow=From-Botnet-V42-TCP-CC1-HTTP-Not-Encrypted
# flow=From-Botnet-V42-TCP-Not-Encrypted-SMTP-Private-Proxy-1
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-40
# flow=From-Botnet-V42-UDP-Established
# flow=From-Botnet-V42-TCP-CC16-HTTP-Not-Encrypted
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-15
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-44
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-16
# flow=From-Botnet-V42-TCP-Established-HTTP-Adobe-4
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-18
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-20
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-37
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-59
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-25
# flow=From-Botnet-V42-TCP-Established-SPAM
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-1
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-yieldmanager-9
# flow=From-Botnet-V42-TCP-Established-HTTP-Binary-Download-Custom-Port-5
# flow=From-Botnet-V42-TCP-HTTP-Not-Encrypted-Down-2
# flow=From-Botnet-V42-TCP-CC55-Custom-Encryption
# flow=From-Botnet-V42-TCP-WEB-Established-SSL
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-12
# flow=From-Botnet-V42-TCP-Established-Custom-Encryption-3
# flow=From-Botnet-V42-TCP-Established-Custom-Encryption-2
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-21
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-55
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-5
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-53
# flow=From-Botnet-V42-TCP-Established-SSL-To-Microsoft-4
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-47
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-30
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-10
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-6
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-51
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-32
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-3
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-57
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-60
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-41
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-61
# flow=From-Botnet-V42-ICMP
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-48
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-28
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-42
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-50
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-7
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-33
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-45
# flow=From-Botnet-V42-UDP-Attempt-DNS
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-52
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-49
# flow=From-Botnet-V42-TCP-Established-HTTP-Ad-34

# %%
print('No. unique SrcAddr:', dsn['SrcAddr'].nunique())
print('No. unique DestAddr:', dsn['DstAddr'].nunique())
# Out:
# No. unique SrcAddr: 542093
# No. unique DestAddr: 119296

# %%
print('Total No. of flows: ', len(dsn))
bot_count = dsn['Label'].apply(lambda x: 1 if 'botnet' in x.lower() else 0)
print('No. of botnet flows: ', bot_count.sum())
# Out:
# Total No. of flows:  2824636
# No. of botnet flows:  40961

# %%
unique_nodes = set(dsn['SrcAddr'].unique()).union(set(dsn['DstAddr'].unique()))
print('No. of unique nodes: ', len(unique_nodes))
# Out:
# No. of unique nodes:  607565

# %%
edge_dsn = dsn[['SrcAddr', 'DstAddr']].drop_duplicates()

# %%
edge_list = [(u,v) for u, v in edge_dsn.values]

# %%
edge_list
# Out:
# [('212.50.71.179', '147.32.84.229'),
#  ('84.13.246.132', '147.32.84.229'),
#  ('217.163.21.35', '147.32.86.194'),
#  ('83.3.77.74', '147.32.85.5'),
#  ('74.89.223.204', '147.32.84.229'),
#  ('66.169.184.207', '147.32.84.229'),
#  ('182.239.167.121', '147.32.84.229'),
#  ('147.32.3.93', '147.32.84.59'),
#  ('24.117.206.20', '147.32.84.229'),
#  ('94.208.78.74', '147.32.84.229'),
#  ('79.129.201.26', '147.32.84.229'),
#  ('147.32.86.194', '217.163.21.35'),
#  ('147.32.80.13', '147.32.84.162'),
#  ('74.200.246.228', '147.32.84.59'),
#  ('77.238.167.32', '147.32.86.194'),
#  ('94.124.104.196', '147.32.84.59'),
#  ('98.127.111.126', '147.32.84.229'),
#  ('123.1.72.4', '147.32.84.229'),
#  ('147.32.84.229', '212.217.56.83'),
#  ('147.32.84.229', '213.142.200.29'),
#  ('147.32.84.229', '93.45.94.195'),
#  ('147.32.84.229', '83.78.136.90'),
#  ('147.32.80.13', '147.32.85.112'),
#  ('217.164.10.229', '147.32.84.229'),
#  ('199.59.148.20', '147.32.84.184'),
#  ('77.100.246.74', '147.32.84.229'),
#  ('58.72.174.152', '147.32.84.229'),
#  ('83.137.254.245', '147.32.84.229'),
#  ('147.32.84.59', '74.125.232.215'),
#  ('147.32.84.138', '147.32.80.9'),
#  ('186.204.215.229', '147.32.84.229'),
#  ('147.32.84.229', '31.9.113.254'),
#  ('109.183.212.236', '147.32.84.130'),
#  ('178.236.4.29', '147.32.86.141'),
#  ('212.59.9.106', '147.32.84.229'),
#  ('147.32.86.111', '147.32.1.20'),
#  ('79.78.83.0', '147.32.84.229'),
#  ('213.192.37.130', '147.32.84.229'),
#  ('147.32.80.9', '147.32.86.111'),
#  ('147.32.86.111', '147.32.80.9'),
#  ('80.37.198.143', '147.32.84.229'),
#  ('72.73.36.9', '147.32.84.229'),
#  ('147.32.84.229', '76.112.233.145'),
#  ('147.32.84.229', '118.168.132.221'),
#  ('147.32.84.59', '69.63.190.10'),
#  ('41.34.128.253', '147.32.84.229'),
#  ('188.134.37.80', '147.32.84.229'),
#  ('92.60.134.17', '147.32.85.5'),
#  ('85.32.91.210', '147.32.84.229'),
#  ('173.30.59.224', '147.32.84.229'),
#  ('118.167.1.65', '147.32.84.229'),
#  ('147.32.84.229', '194.179.126.154'),
#  ('147.32.84.229', '81.104.184.70'),
#  ('147.32.84.229', '145.53.199.214'),
#  ('147.32.84.229', '90.42.60.138'),
#  ('81.96.196.10', '147.32.84.229'),
#  ('147.32.86.194', '195.113.232.96'),
#  ('77.37.201.25', '147.32.84.229'),
#  ('147.32.84.229', '216.113.82.229'),
#  ('212.170.156.80', '147.32.84.229'),
#  ('95.31.15.58', '147.32.84.229'),
#  ('86.177.90.166', '147.32.84.229'),
#  ('147.32.84.59', '188.11.68.124'),
#  ('90.183.101.184', '147.32.86.89'),
#  ('81.12.164.18', '147.32.84.229'),
#  ('147.32.84.229', '77.85.252.195'),
#  ('201.243.98.47', '147.32.84.229'),
#  ('118.209.60.180', '147.32.84.229'),
#  ('77.85.152.108', '147.32.84.229'),
#  ('65.189.197.181', '147.32.84.229'),
#  ('147.32.84.229', '81.30.240.226'),
#  ('213.123.60.93', '147.32.84.229'),
#  ('84.43.145.215', '147.32.84.229'),
#  ('83.55.71.107', '147.32.84.229'),
#  ('211.75.185.229', '147.32.84.229'),
#  ('81.6.98.107', '147.32.84.229'),
#  ('196.201.203.98', '147.32.84.229'),
#  ('80.27.103.28', '147.32.84.229'),
#  ('24.228.42.112', '147.32.84.229'),
#  ('74.125.232.215', '147.32.85.5'),
#  ('217.203.159.131', '147.32.85.84'),
#  ('120.203.91.212', '147.32.84.229'),
#  ('212.55.237.42', '147.32.84.229'),
#  ('147.32.84.146', '208.75.88.4'),
#  ('147.32.84.229', '90.146.174.188'),
#  ('88.102.51.188', '147.32.87.36'),
#  ('79.47.168.89', '147.32.84.229'),
#  ('76.107.202.45', '147.32.84.229'),
#  ('147.32.84.229', '88.201.182.160'),
#  ('147.32.84.229', '89.236.217.18'),
#  ('77.124.34.143', '147.32.84.229'),
#  ('94.165.57.146', '147.32.85.56'),
#  ('213.118.148.252', '147.32.84.229'),
#  ('195.250.146.99', '147.32.86.99'),
#  ('147.32.85.47', '170.107.181.167'),
#  ('122.49.161.50', '147.32.84.229'),
#  ('147.32.84.242', '78.108.97.41'),
#  ('83.83.100.36', '147.32.84.229'),
#  ('147.32.86.84', '74.125.232.194'),
#  ('147.32.84.59', '151.64.186.190'),
#  ('119.247.92.207', '147.32.84.229'),
#  ('147.32.86.147', '74.125.232.194'),
#  ('147.32.87.1', '224.0.0.13'),
#  ('147.32.85.30', '147.32.80.9'),
#  ('84.215.89.9', '147.32.84.229'),
#  ('147.32.84.229', '98.127.111.126'),
#  ('147.32.84.59', '81.171.72.12'),
#  ('147.32.86.194', '147.32.80.9'),
#  ('147.32.86.20', '147.32.80.9'),
#  ('147.32.86.20', '87.98.230.229'),
#  ('147.32.86.99', '147.32.80.9'),
#  ('147.32.84.59', '62.107.124.67'),
#  ('147.32.84.59', '205.188.10.245'),
#  ('147.32.84.229', '111.255.7.126'),
#  ('147.32.84.229', '212.178.10.94'),
#  ('124.183.252.245', '147.32.84.229'),
#  ('147.32.84.229', '124.183.252.245'),
#  ('147.32.84.229', '213.113.105.210'),
#  ('85.74.30.252', '147.32.84.229'),
#  ('114.42.219.244', '147.32.84.229'),
#  ('184.242.33.131', '147.32.84.229'),
#  ('89.236.150.110', '147.32.84.229'),
#  ('89.169.38.183', '147.32.84.229'),
#  ('210.49.167.41', '147.32.84.229'),
#  ('114.43.207.165', '147.32.84.229'),
#  ('147.32.86.111', '213.200.111.122'),
#  ('77.124.131.205', '147.32.84.229'),
#  ('78.108.97.41', '147.32.84.242'),
#  ('147.32.85.30', '195.113.232.80'),
#  ('213.160.160.151', '147.32.84.229'),
#  ('147.32.84.229', '195.91.109.154'),
#  ('74.201.117.247', '147.32.84.59'),
#  ('147.32.84.229', '140.164.56.22'),
#  ('147.32.84.229', '115.87.194.179'),
#  ('147.32.84.229', '183.88.0.239'),
#  ('147.32.84.229', '78.141.181.223'),
#  ('147.32.84.229', '118.165.97.144'),
#  ('147.32.84.229', '91.127.111.247'),
#  ('147.32.84.229', '91.192.219.27'),
#  ('147.32.84.229', '114.27.75.221'),
#  ('147.32.84.229', '195.112.110.248'),
#  ('66.249.66.241', '147.32.86.92'),
#  ('174.53.233.126', '147.32.84.229'),
#  ('187.105.22.143', '147.32.84.229'),
#  ('74.125.232.216', '147.32.84.68'),
#  ('60.229.10.85', '147.32.84.229'),
#  ('95.60.148.50', '147.32.84.229'),
#  ('147.32.84.68', '74.125.232.216'),
#  ('213.220.212.174', '147.32.84.229'),
#  ('213.162.68.167', '147.32.84.229'),
#  ('178.96.223.191', '147.32.84.229'),
#  ('79.132.0.50', '147.32.84.229'),
#  ('95.174.209.49', '147.32.84.229'),
#  ('93.155.164.122', '147.32.84.229'),
#  ('87.50.100.122', '147.32.84.229'),
#  ('79.130.2.158', '147.32.84.229'),
#  ('151.62.24.42', '147.32.84.229'),
#  ('147.32.84.229', '111.81.72.250'),
#  ('147.32.84.229', '85.71.29.123'),
#  ('147.32.84.229', '62.134.46.4'),
#  ('147.32.84.229', '193.198.99.10'),
#  ('147.32.84.229', '213.181.225.101'),
#  ('77.220.30.250', '147.32.84.229'),
#  ('147.32.84.59', '92.43.56.151'),
#  ('91.148.160.38', '147.32.84.229'),
#  ('196.210.180.92', '147.32.84.229'),
#  ('128.122.184.9', '147.32.84.229'),
#  ('80.249.83.9', '147.32.84.229'),
#  ('147.32.84.229', '124.26.221.218'),
#  ('74.125.39.125', '147.32.84.59'),
#  ('91.138.241.52', '147.32.84.229'),
#  ('74.125.232.202', '147.32.84.59'),
#  ('147.32.84.59', '173.194.1.37'),
#  ('79.129.109.30', '147.32.84.229'),
#  ('208.88.186.8', '147.32.84.229'),
#  ('94.155.50.233', '147.32.84.229'),
#  ('66.65.140.99', '147.32.84.229'),
#  ('195.250.146.6', '147.32.84.59'),
#  ('218.160.246.114', '147.32.84.229'),
#  ('193.84.86.14', '147.32.84.229'),
#  ('147.32.84.229', '193.84.86.14'),
#  ('194.228.143.168', '147.32.84.229'),
#  ('93.109.110.181', '147.32.84.229'),
#  ('147.32.84.229', '58.170.170.187'),
#  ('89.215.71.16', '147.32.84.229'),
#  ('147.32.84.229', '71.66.228.58'),
#  ('213.255.82.46', '147.32.84.229'),
#  ('89.28.105.80', '147.32.84.229'),
#  ('147.32.84.229', '93.56.35.22'),
#  ('89.45.153.140', '147.32.84.229'),
#  ('147.32.80.13', '147.32.84.3'),
#  ('147.32.80.13', '147.32.84.138'),
#  ('147.32.84.138', '147.32.80.13'),
#  ('147.32.84.3', '147.32.80.13'),
#  ('60.247.101.19', '147.32.84.229'),
#  ('78.141.179.8', '147.32.84.229'),
#  ('72.55.140.87', '147.32.84.229'),
#  ('124.155.44.8', '147.32.84.229'),
#  ('147.32.84.229', '94.111.102.205'),
#  ('84.153.166.239', '147.32.86.165'),
#  ('147.32.86.187', '195.113.232.82'),
#  ('147.32.84.16', '147.32.80.9'),
#  ('147.32.84.16', '147.32.192.127'),
#  ('147.32.84.19', '89.24.7.87'),
#  ('84.123.27.242', '147.32.84.229'),
#  ('147.32.84.229', '81.165.46.181'),
#  ('89.208.216.118', '147.32.84.229'),
#  ('171.64.245.206', '147.32.84.229'),
#  ('2.104.91.251', '147.32.84.229'),
#  ('217.165.88.133', '147.32.84.229'),
#  ('147.32.87.40', '147.231.100.5'),
#  ('95.148.153.79', '147.32.84.229'),
#  ('147.32.84.229', '88.216.50.69'),
#  ('98.243.178.193', '147.32.84.229'),
#  ('93.97.178.23', '147.32.84.229'),
#  ('147.32.84.25', '147.32.80.9'),
#  ('147.32.84.25', '74.125.232.215'),
#  ('76.200.191.26', '147.32.84.229'),
#  ('99.169.203.10', '147.32.84.229'),
#  ('174.7.122.164', '147.32.84.229'),
#  ('83.240.71.78', '147.32.84.229'),
#  ('119.30.39.87', '147.32.84.229'),
#  ('195.160.252.45', '147.32.84.229'),
#  ('220.134.36.115', '147.32.86.165'),
#  ('147.32.85.30', '209.85.148.147'),
#  ('147.32.85.30', '69.63.190.10'),
#  ('147.32.192.127', '147.32.84.59'),
#  ('115.108.3.145', '147.32.84.229'),
#  ('147.32.84.229', '2.220.218.105'),
#  ('147.32.85.84', '67.165.21.169'),
#  ('147.32.85.84', '192.0.1.0'),
#  ('195.113.235.89', '147.32.85.84'),
#  ('58.186.182.107', '147.32.84.229'),
#  ('195.212.29.188', '147.32.84.229'),
#  ('147.32.84.46', '147.32.3.51'),
#  ('175.145.89.85', '147.32.84.229'),
#  ('212.248.66.74', '147.32.84.229'),
#  ('46.35.166.79', '147.32.84.229'),
#  ('2.102.41.58', '147.32.84.229'),
#  ('147.32.84.59', '147.32.96.112'),
#  ('213.16.245.175', '147.32.84.229'),
#  ('147.32.87.78', '147.32.87.78'),
#  ('147.32.84.229', '195.251.161.149'),
#  ('147.32.84.229', '149.5.45.6'),
#  ('217.203.136.107', '147.32.84.229'),
#  ('123.26.255.254', '147.32.84.229'),
#  ('62.83.145.131', '147.32.84.229'),
#  ('78.145.243.255', '147.32.84.229'),
#  ('147.32.85.124', '109.123.209.192'),
#  ('80.188.106.191', '147.32.84.229'),
#  ('00:15:17:2c:e5:2d', 'ff:ff:ff:ff:ff:ff'),
#  ('147.32.84.229', '41.8.74.49'),
#  ('147.32.84.229', '150.217.155.122'),
#  ('96.60.136.148', '147.32.84.229'),
#  ('147.32.84.229', '114.24.72.145'),
#  ('147.32.84.59', '209.85.148.105'),
#  ('147.32.85.84', '151.48.137.187'),
#  ('147.32.84.229', '123.189.142.158'),
#  ('147.32.84.229', '93.79.152.94'),
#  ('183.12.36.153', '147.32.84.229'),
#  ('147.32.86.147', '74.125.232.193'),
#  ('147.32.86.147', '209.85.148.132'),
#  ('46.33.9.47', '147.32.84.229'),
#  ('95.71.241.9', '147.32.84.229'),
#  ('120.199.59.206', '147.32.84.229'),
#  ('111.255.4.75', '147.32.84.229'),
#  ('109.186.40.38', '147.32.84.229'),
#  ('147.32.85.30', '195.113.232.89'),
#  ('84.206.26.34', '147.32.84.229'),
#  ('217.118.66.6', '147.32.84.229'),
#  ('74.125.232.216', '147.32.84.59'),
#  ('125.54.100.88', '147.32.84.229'),
#  ('147.32.84.229', '129.120.60.186'),
#  ('147.32.84.229', '82.11.43.18'),
#  ('98.240.179.234', '147.32.84.229'),
#  ('79.100.184.252', '147.32.84.229'),
#  ('147.32.84.59', '77.78.110.71'),
#  ('121.215.17.148', '147.32.84.229'),
#  ('58.60.198.72', '147.32.84.229'),
#  ('41.191.77.250', '147.32.84.229'),
#  ('95.170.214.140', '147.32.84.229'),
#  ('192.168.88.176', '192.168.95.255'),
#  ('77.122.53.11', '147.32.84.229'),
#  ('147.32.84.229', '82.139.115.3'),
#  ('147.32.84.229', '82.18.90.13'),
#  ('147.32.84.229', '97.100.200.67'),
#  ('147.32.84.229', '68.81.243.44'),
#  ('147.32.84.229', '98.218.13.249'),
#  ('147.32.84.229', '96.51.56.43'),
#  ('147.32.84.229', '130.88.16.50'),
#  ('147.32.84.229', '62.228.38.56'),
#  ('80.188.216.82', '147.32.84.185'),
#  ('77.37.170.129', '147.32.84.229'),
#  ('89.169.182.86', '147.32.84.229'),
#  ('95.26.115.142', '147.32.84.229'),
#  ('147.32.84.229', '178.177.129.21'),
#  ('89.106.42.214', '147.32.84.229'),
#  ('93.147.166.209', '147.32.84.229'),
#  ('41.95.4.92', '147.32.84.229'),
#  ('147.32.84.229', '99.252.136.199'),
#  ('147.32.84.229', '76.111.238.233'),
#  ('94.193.3.209', '147.32.84.229'),
#  ('86.0.11.249', '147.32.84.229'),
#  ('118.8.77.39', '147.32.84.229'),
#  ('147.32.85.2', '147.32.3.12'),
#  ('195.184.103.83', '147.32.84.229'),
#  ('217.44.209.240', '147.32.84.229'),
#  ('114.76.216.157', '147.32.84.229'),
#  ('147.32.84.229', '188.186.64.152'),
#  ('24.209.66.158', '147.32.84.229'),
#  ('188.232.22.54', '147.32.84.229'),
#  ('27.97.233.16', '147.32.84.229'),
#  ('147.32.84.229', '99.244.47.71'),
#  ('147.32.84.229', '83.86.44.128'),
#  ('147.32.84.229', '122.118.178.112'),
#  ('109.121.253.211', '147.32.84.229'),
#  ('147.32.84.229', '195.158.106.114'),
#  ('110.162.192.198', '147.32.84.229'),
#  ('213.208.109.185', '147.32.84.229'),
#  ('62.168.2.186', '147.32.84.199'),
#  ('147.32.85.30', '2.20.182.40'),
#  ('147.32.84.229', '174.5.129.250'),
#  ('147.32.84.229', '149.5.45.254'),
#  ('94.180.65.173', '147.32.84.229'),
#  ('93.158.144.28', '147.32.84.2'),
#  ('193.247.250.17', '147.32.84.229'),
#  ('98.177.216.25', '147.32.84.229'),
#  ('147.32.84.2', '212.71.128.157'),
#  ('109.157.29.69', '147.32.84.229'),
#  ('70.226.167.232', '147.32.84.229'),
#  ('147.32.84.229', '217.231.154.128'),
#  ('195.238.84.210', '147.32.84.229'),
#  ('79.100.136.228', '147.32.84.229'),
#  ('125.17.174.6', '147.32.84.229'),
#  ('220.236.61.129', '147.32.84.229'),
#  ('92.96.97.165', '147.32.84.229'),
#  ('195.113.144.245', '147.32.84.59'),
#  ('199.40.206.187', '147.32.84.229'),
#  ('91.210.137.14', '147.32.84.229'),
#  ('109.113.27.149', '147.32.84.229'),
#  ('147.32.84.229', '201.252.157.186'),
#  ('147.32.84.229', '151.26.21.72'),
#  ('114.24.107.16', '147.32.84.229'),
#  ('151.81.105.200', '147.32.84.229'),
#  ('147.32.84.59', '66.220.153.11'),
#  ('147.32.84.229', '93.74.51.190'),
#  ('147.32.84.229', '95.149.171.238'),
#  ('78.128.2.14', '147.32.84.229'),
#  ('12.230.57.12', '147.32.84.229'),
#  ('213.30.151.162', '147.32.84.229'),
#  ('147.32.84.229', '82.216.189.11'),
#  ('147.32.84.229', '207.183.160.230'),
#  ('147.32.84.229', '89.252.235.183'),
#  ('147.32.84.229', '69.80.132.119'),
#  ('94.155.63.154', '147.32.84.229'),
#  ('213.85.213.210', '147.32.84.229'),
#  ('147.32.84.229', '208.88.186.11'),
#  ('147.32.84.229', '140.134.44.50'),
#  ('91.74.179.98', '147.32.84.229'),
#  ('41.212.41.19', '147.32.84.229'),
#  ('109.178.45.86', '147.32.84.229'),
#  ('128.59.207.225', '147.32.84.229'),
#  ('147.32.84.229', '77.220.7.181'),
#  ('208.77.59.237', '147.32.84.229'),
#  ('125.24.127.12', '147.32.84.229'),
#  ('184.95.21.167', '147.32.84.229'),
#  ('188.173.55.102', '147.32.84.229'),
#  ('147.32.84.229', '134.2.151.44'),
#  ('147.32.84.229', '67.251.3.114'),
#  ('147.32.84.229', '187.10.188.4'),
#  ('147.32.84.229', '85.225.119.250'),
#  ('147.32.84.229', '90.3.250.232'),
#  ('147.32.84.229', '90.154.225.37'),
#  ('147.32.84.166', '194.108.204.19'),
#  ('147.32.84.229', '122.134.56.252'),
#  ('41.243.108.162', '147.32.84.229'),
#  ('46.50.189.29', '147.32.84.229'),
#  ('147.32.85.25', '147.32.80.9'),
#  ('82.24.148.53', '147.32.84.229'),
#  ('81.218.229.68', '147.32.86.92'),
#  ('147.32.87.53', '81.218.229.68'),
#  ('178.134.54.19', '147.32.84.229'),
#  ('147.32.84.229', '69.118.215.200'),
#  ('147.32.86.99', '74.125.232.197'),
#  ('147.32.84.134', '147.32.80.9'),
#  ('147.32.84.134', '88.86.100.176'),
#  ('60.251.239.44', '147.32.84.229'),
#  ('213.146.167.10', '147.32.84.229'),
#  ('121.219.225.37', '147.32.84.229'),
#  ('83.89.98.199', '147.32.84.229'),
#  ('83.97.31.111', '147.32.84.229'),
#  ('147.32.85.5', '58.65.159.13'),
#  ('2.92.137.171', '147.32.84.229'),
#  ('85.180.145.244', '147.32.84.229'),
#  ('24.78.200.75', '147.32.84.229'),
#  ('78.26.213.255', '147.32.84.229'),
#  ('82.147.134.26', '147.32.84.229'),
#  ('147.32.85.124', '67.221.174.61'),
#  ('147.32.85.124', '66.220.151.99'),
#  ('147.32.85.124', '74.125.39.125'),
#  ('66.249.66.51', '147.32.84.242'),
#  ('147.32.84.154', '89.187.142.41'),
#  ('147.32.85.30', '195.113.232.73'),
#  ('82.195.234.51', '147.32.84.229'),
#  ('188.176.69.225', '147.32.84.229'),
#  ('74.125.232.213', '147.32.84.131'),
#  ('147.32.84.229', '109.191.238.141'),
#  ('58.41.168.131', '147.32.84.229'),
#  ('92.19.62.214', '147.32.84.229'),
#  ('92.62.229.77', '147.32.84.229'),
#  ('77.78.161.48', '147.32.84.229'),
#  ('147.32.84.229', '212.39.97.7'),
#  ('217.197.149.2', '147.32.84.229'),
#  ('122.106.106.139', '147.32.84.229'),
#  ('182.177.112.36', '147.32.84.229'),
#  ('196.201.131.184', '147.32.84.229'),
#  ('80.122.54.50', '147.32.84.229'),
#  ('147.32.84.229', '186.25.153.129'),
#  ('147.32.84.229', '58.84.129.74'),
#  ('147.32.84.229', '99.255.102.185'),
#  ('147.32.84.229', '149.5.45.251'),
#  ('147.32.86.99', '89.185.234.107'),
#  ('77.21.32.22', '147.32.84.229'),
#  ('2.220.218.105', '147.32.84.229'),
#  ('147.32.84.229', '134.83.236.5'),
#  ('213.111.221.89', '147.32.84.229'),
#  ('223.204.82.118', '147.32.84.229'),
#  ('62.12.137.130', '147.32.84.229'),
#  ('217.118.64.51', '147.32.84.229'),
#  ('192.168.84.94', '192.168.95.255'),
#  ('213.114.169.1', '147.32.84.229'),
#  ('94.14.21.184', '147.32.84.229'),
#  ('147.32.86.20', '188.138.84.239'),
#  ('121.12.167.228', '147.32.84.229'),
#  ('212.23.65.217', '147.32.84.229'),
#  ('77.220.0.174', '147.32.84.229'),
#  ('83.71.102.31', '147.32.84.229'),
#  ('178.169.132.198', '147.32.84.229'),
#  ('41.199.149.49', '147.32.84.229'),
#  ('193.120.212.19', '147.32.84.229'),
#  ('222.165.44.240', '147.32.84.229'),
#  ('92.81.97.226', '147.32.84.229'),
#  ('190.18.214.74', '147.32.84.229'),
#  ('195.1.47.250', '147.32.84.229'),
#  ('192.168.88.67', '192.168.95.255'),
#  ('147.32.84.229', '193.73.242.1'),
#  ('188.2.125.31', '147.32.84.229'),
#  ('87.254.166.174', '147.32.84.229'),
#  ('118.98.168.83', '147.32.86.165'),
#  ('188.169.144.112', '147.32.84.229'),
#  ('151.62.43.234', '147.32.84.229'),
#  ('88.159.162.238', '147.32.84.229'),
#  ('78.106.71.198', '147.32.84.229'),
#  ('2.20.182.35', '147.32.84.59'),
#  ('59.137.182.72', '147.32.84.229'),
#  ('147.32.84.229', '88.174.44.97'),
#  ('203.160.61.150', '147.32.84.229'),
#  ('204.9.163.214', '147.32.84.229'),
#  ('220.245.135.225', '147.32.84.59'),
#  ('147.32.84.59', '220.245.135.225'),
#  ('71.34.88.196', '147.32.85.124'),
#  ('147.32.85.124', '71.34.88.196'),
#  ('89.185.234.107', '147.32.86.99'),
#  ('95.72.42.218', '147.32.84.229'),
#  ('62.12.72.75', '147.32.84.229'),
#  ('86.162.180.196', '147.32.84.229'),
#  ('147.32.84.229', '86.158.41.164'),
#  ('72.145.176.100', '147.32.84.229'),
#  ('108.41.164.45', '147.32.84.229'),
#  ('147.32.84.229', '24.57.40.195'),
#  ('147.32.84.229', '85.129.70.159'),
#  ('64.13.161.54', '147.32.84.229'),
#  ('147.32.84.229', '130.83.254.49'),
#  ('79.100.192.195', '147.32.84.229'),
#  ('147.32.84.229', '196.201.133.134'),
#  ('118.169.53.10', '147.32.84.229'),
#  ('211.10.164.160', '147.32.84.229'),
#  ('79.131.218.72', '147.32.84.229'),
#  ('14.221.222.181', '147.32.84.229'),
#  ('78.141.177.64', '147.32.84.229'),
#  ('69.254.202.111', '147.32.84.229'),
#  ('83.197.255.250', '147.32.84.229'),
#  ('188.193.48.108', '147.32.84.229'),
#  ('96.22.78.102', '147.32.84.229'),
#  ('85.156.87.146', '147.32.84.229'),
#  ('213.198.208.108', '147.32.84.229'),
#  ('60.230.127.29', '147.32.84.229'),
#  ('83.228.22.148', '147.32.84.229'),
#  ('62.168.31.70', '147.32.84.229'),
#  ('147.32.85.2', '217.20.66.200'),
#  ('147.32.85.2', '203.208.85.19'),
#  ('84.51.123.209', '147.32.84.229'),
#  ('72.48.78.3', '147.32.84.229'),
#  ('188.62.144.29', '147.32.84.229'),
#  ('147.32.84.229', '86.144.214.247'),
#  ('147.32.84.229', '129.237.148.26'),
#  ('147.32.84.229', '128.100.102.167'),
#  ('147.32.84.229', '111.216.254.106'),
#  ('27.251.165.234', '147.32.84.229'),
#  ('200.110.34.192', '147.32.86.165'),
#  ('122.224.198.70', '147.32.84.229'),
#  ('147.32.80.13', '147.32.85.113'),
#  ('46.13.90.44', '147.32.84.229'),
#  ('89.215.54.109', '147.32.84.229'),
#  ('124.130.163.223', '147.32.84.229'),
#  ('147.32.84.229', '68.24.131.130'),
#  ('189.21.194.65', '147.32.84.229'),
#  ('217.253.21.130', '147.32.84.229'),
#  ('82.150.201.1', '147.32.84.229'),
#  ('46.202.194.159', '147.32.84.229'),
#  ('147.32.84.229', '201.1.197.250'),
#  ('70.181.100.200', '147.32.84.229'),
#  ('77.78.30.205', '147.32.84.229'),
#  ('99.66.156.195', '147.32.84.229'),
#  ('147.32.86.147', '74.125.232.203'),
#  ('147.32.86.147', '209.85.148.99'),
#  ('125.226.30.237', '147.32.84.229'),
#  ('220.128.219.107', '147.32.84.229'),
#  ('93.100.235.128', '147.32.84.229'),
#  ('58.173.52.172', '147.32.84.229'),
#  ('86.156.32.171', '147.32.84.229'),
#  ('218.206.126.104', '147.32.84.229'),
#  ('59.15.90.124', '147.32.84.229'),
#  ('147.32.84.229', '83.165.138.18'),
#  ('24.190.223.160', '147.32.84.229'),
#  ('147.32.86.147', '77.238.160.184'),
#  ('88.151.189.89', '147.32.84.229'),
#  ('81.177.144.185', '147.32.84.229'),
#  ('212.5.131.209', '147.32.84.229'),
#  ('188.86.20.201', '147.32.84.59'),
#  ('147.32.84.59', '188.86.20.201'),
#  ('89.0.145.111', '147.32.84.111'),
#  ('147.32.84.229', '122.118.184.103'),
#  ('147.32.86.99', '74.206.183.250'),
#  ('119.228.16.3', '147.32.86.208'),
#  ('109.74.133.194', '147.32.84.229'),
#  ('68.52.88.162', '147.32.84.59'),
#  ('74.57.168.175', '147.32.84.229'),
#  ('147.32.84.229', '217.128.68.79'),
#  ('152.1.124.125', '147.32.84.229'),
#  ('80.232.167.196', '147.32.84.229'),
#  ('147.32.86.147', '74.125.232.192'),
#  ('188.133.23.52', '147.32.84.229'),
#  ('147.32.85.87', '209.85.148.99'),
#  ('90.3.250.232', '147.32.84.229'),
#  ('147.32.85.30', '195.113.232.98'),
#  ('82.127.161.26', '147.32.84.59'),
#  ('62.110.136.4', '147.32.84.229'),
#  ('147.32.84.59', '82.127.161.26'),
#  ('121.215.219.23', '147.32.84.229'),
#  ('209.85.148.105', '147.32.84.59'),
#  ('194.95.66.1', '147.32.85.84'),
#  ('147.32.84.59', '130.83.162.133'),
#  ('188.26.130.234', '147.32.84.229'),
#  ('147.32.84.2', '206.53.152.171'),
#  ('46.33.32.100', '147.32.84.229'),
#  ('195.59.102.18', '147.32.84.229'),
#  ('147.32.84.229', '83.251.160.20'),
#  ('80.169.46.3', '147.32.84.229'),
#  ('94.243.234.142', '147.32.84.229'),
#  ('66.220.151.82', '147.32.84.59'),
#  ('68.165.223.10', '147.32.84.229'),
#  ('109.236.84.83', '147.32.85.100'),
#  ('147.32.84.229', '208.53.238.94'),
#  ('147.32.84.229', '189.78.115.203'),
#  ('147.32.84.59', '129.241.173.237'),
#  ('80.202.134.29', '147.32.84.229'),
#  ('147.32.86.20', '193.93.174.21'),
#  ('58.165.30.164', '147.32.84.229'),
#  ('41.77.8.213', '147.32.84.229'),
#  ('41.15.18.28', '147.32.84.229'),
#  ('193.106.67.236', '147.32.84.229'),
#  ('217.114.234.180', '147.32.84.229'),
#  ('113.119.179.107', '147.32.84.229'),
#  ('79.167.25.14', '147.32.84.229'),
#  ('147.32.84.59', '173.52.28.177'),
#  ('147.32.86.99', '78.24.9.177'),
#  ('88.109.10.23', '147.32.84.229'),
#  ('87.106.150.17', '147.32.84.59'),
#  ('147.32.86.147', '74.125.232.204'),
#  ('78.141.179.11', '147.32.84.59'),
#  ('147.32.87.21', '147.32.3.51'),
#  ('208.88.186.11', '147.32.84.229'),
#  ('147.32.84.229', '78.107.232.175'),
#  ('147.32.84.229', '46.73.21.11'),
#  ('81.88.224.85', '147.32.84.229'),
#  ('147.32.84.59', '62.44.1.24'),
#  ('80.109.100.208', '147.32.84.229'),
#  ('121.243.26.254', '147.32.84.229'),
#  ('98.83.218.204', '147.32.84.229'),
#  ('84.242.66.38', '147.32.84.242'),
#  ('147.32.252.254', '147.32.84.59'),
#  ('92.226.32.204', '147.32.84.229'),
#  ('86.174.129.139', '147.32.84.229'),
#  ('188.17.64.146', '147.32.84.229'),
#  ('147.32.86.147', '74.125.232.205'),
#  ('130.159.17.136', '147.32.84.229'),
#  ('147.32.84.229', '24.95.69.169'),
#  ('147.32.84.229', '92.253.93.43'),
#  ('95.88.125.154', '147.32.84.229'),
#  ('147.32.84.229', '93.103.150.167'),
#  ('82.193.98.222', '147.32.84.229'),
#  ('113.213.248.179', '147.32.84.229'),
#  ('82.7.84.251', '147.32.84.59'),
#  ('92.247.162.171', '147.32.84.229'),
#  ('64.12.68.227', '147.32.84.59'),
#  ('192.168.88.51', '192.168.95.255'),
#  ('147.32.84.229', '114.180.147.167'),
#  ('147.32.84.229', '74.57.0.113'),
#  ('147.32.84.229', '41.57.135.41'),
#  ('77.85.89.138', '147.32.84.229'),
#  ('147.32.84.229', '208.38.252.32'),
#  ('147.32.84.59', '94.26.69.142'),
#  ('59.162.55.149', '147.32.84.229'),
#  ('89.138.0.254', '147.32.84.229'),
#  ('70.94.64.113', '147.32.84.229'),
#  ('129.8.39.17', '147.32.84.229'),
#  ('118.6.44.195', '147.32.84.229'),
#  ('80.169.224.226', '147.32.84.229'),
#  ('169.229.223.168', '147.32.84.19'),
#  ('147.32.84.20', '212.96.160.147'),
#  ('147.32.84.131', '74.125.232.215'),
#  ('147.32.84.131', '209.85.148.103'),
#  ('147.32.84.229', '24.252.141.26'),
#  ('147.32.84.229', '68.43.151.53'),
#  ('147.32.84.229', '78.141.181.222'),
#  ('85.187.40.240', '147.32.84.229'),
#  ('147.32.84.59', '2.20.182.50'),
#  ('213.91.186.101', '147.32.84.229'),
#  ('147.32.84.59', '147.32.80.9'),
#  ('80.91.212.22', '147.32.84.229'),
#  ('147.32.84.59', '92.123.64.155'),
#  ('147.32.84.59', '195.113.232.82'),
#  ('120.56.193.66', '147.32.84.229'),
#  ('147.32.84.59', '2.21.99.206'),
#  ('78.63.108.241', '147.32.84.229'),
#  ('188.186.94.254', '147.32.84.229'),
#  ('147.32.84.229', '91.37.163.15'),
#  ('111.240.236.177', '147.32.84.229'),
#  ('95.42.51.241', '147.32.84.229'),
#  ('147.32.84.229', '193.68.14.110'),
#  ('46.10.38.81', '147.32.84.229'),
#  ('31.9.113.254', '147.32.84.229'),
#  ('213.204.121.120', '147.32.84.229'),
#  ('147.32.84.229', '115.165.46.115'),
#  ('147.32.84.229', '92.226.101.144'),
#  ('147.32.84.229', '125.4.22.86'),
#  ('147.32.84.229', '151.48.20.62'),
#  ('93.157.87.33', '147.32.84.229'),
#  ('62.109.87.41', '147.32.84.229'),
#  ('95.42.226.199', '147.32.84.229'),
#  ('74.125.232.216', '147.32.84.134'),
#  ('188.123.134.226', '147.32.84.229'),
#  ('147.32.84.229', '82.2.193.184'),
#  ('147.32.84.229', '41.81.61.134'),
#  ('147.32.84.229', '188.131.108.240'),
#  ('178.254.232.7', '147.32.84.229'),
#  ('91.112.101.74', '147.32.84.229'),
#  ('24.148.7.211', '147.32.84.229'),
#  ('213.85.188.227', '147.32.84.229'),
#  ('109.169.129.198', '147.32.84.229'),
#  ('183.11.129.204', '147.32.84.229'),
#  ('147.32.84.229', '94.228.236.65'),
#  ('147.32.84.229', '84.194.119.216'),
#  ('77.85.159.20', '147.32.84.229'),
#  ('147.32.86.96', '147.32.87.38'),
#  ('147.32.87.1', '147.32.87.38'),
#  ('98.210.179.62', '147.32.84.229'),
#  ('212.233.208.134', '147.32.84.229'),
#  ('124.149.81.146', '147.32.84.229'),
#  ('205.188.11.62', '147.32.84.189'),
#  ('149.5.45.5', '147.32.84.229'),
#  ('140.124.61.164', '147.32.84.229'),
#  ('66.220.151.83', '147.32.84.179'),
#  ('46.20.110.172', '147.32.84.229'),
#  ('147.32.84.229', '186.59.151.90'),
#  ('80.92.182.12', '147.32.84.229'),
#  ('147.32.84.229', '118.232.188.176'),
#  ('147.32.84.229', '126.60.240.66'),
#  ('147.32.84.229', '125.201.122.125'),
#  ('147.32.85.87', '147.32.80.9'),
#  ('188.187.112.20', '147.32.84.229'),
#  ('58.166.100.150', '147.32.84.229'),
#  ('218.102.68.207', '147.32.84.229'),
#  ('151.49.153.247', '147.32.84.229'),
#  ('147.32.85.103', '88.159.8.10'),
#  ('79.100.119.110', '147.32.84.229'),
#  ('212.178.10.94', '147.32.84.229'),
#  ('87.126.188.142', '147.32.84.229'),
#  ('81.53.102.220', '147.32.84.229'),
#  ('147.32.84.156', '212.96.160.147'),
#  ('202.53.82.98', '147.32.84.229'),
#  ('41.190.88.245', '147.32.84.229'),
#  ('85.118.193.177', '147.32.84.229'),
#  ('203.116.30.206', '147.32.84.229'),
#  ('86.101.35.17', '147.32.84.229'),
#  ('41.206.86.201', '147.32.84.229'),
#  ('174.88.6.164', '147.32.84.229'),
#  ('199.47.216.149', '147.32.86.172'),
#  ('194.230.155.5', '147.32.84.229'),
#  ('70.165.122.121', '147.32.84.229'),
#  ('222.152.132.194', '147.32.84.229'),
#  ('147.32.86.99', '74.125.232.220'),
#  ('58.145.143.106', '147.32.84.229'),
#  ('110.38.137.160', '147.32.84.229'),
#  ('147.32.86.99', '209.85.149.95'),
#  ('84.238.212.242', '147.32.84.229'),
#  ('91.83.191.67', '147.32.84.229'),
#  ('147.32.86.99', '88.86.106.212'),
#  ('82.152.133.73', '147.32.84.229'),
#  ('178.210.148.127', '147.32.84.229'),
#  ('147.32.80.13', '147.32.84.194'),
#  ('147.32.87.29', '147.32.87.63'),
#  ('147.32.84.229', '213.111.129.15'),
#  ('118.166.240.217', '147.32.84.229'),
#  ('112.211.219.82', '147.32.84.229'),
#  ('147.32.84.229', '83.30.9.18'),
#  ('147.32.84.229', '78.141.179.11'),
#  ('147.32.84.229', '68.57.144.138'),
#  ('123.120.169.23', '147.32.84.229'),
#  ('88.180.1.157', '147.32.84.229'),
#  ('77.67.32.162', '147.32.84.229'),
#  ('81.0.223.29', '147.32.84.229'),
#  ('147.32.84.59', '78.102.53.70'),
#  ('147.32.84.59', '78.102.90.224'),
#  ('186.205.227.217', '147.32.84.229'),
#  ('87.64.128.204', '147.32.84.229'),
#  ('147.32.80.7', '147.32.84.59'),
#  ('77.56.131.169', '147.32.84.229'),
#  ('65.54.49.96', '147.32.86.99'),
#  ('188.53.34.104', '147.32.85.124'),
#  ('147.32.85.124', '188.53.34.104'),
#  ('203.96.54.175', '147.32.84.229'),
#  ('41.215.60.106', '147.32.84.229'),
#  ('147.32.85.124', '74.125.232.192'),
#  ('95.59.201.37', '147.32.84.229'),
#  ('147.32.86.171', '129.241.62.54'),
#  ('80.137.117.219', '147.32.84.229'),
#  ('76.194.240.235', '147.32.84.229'),
#  ('147.32.84.229', '178.167.41.81'),
#  ('84.110.1.31', '147.32.84.229'),
#  ('147.32.84.229', '217.27.32.207'),
#  ('88.102.29.2', '147.32.84.229'),
#  ('92.251.46.35', '147.32.84.229'),
#  ('147.32.84.164', '74.125.232.216'),
#  ('87.111.156.12', '147.32.84.229'),
#  ('80.254.146.36', '147.32.86.99'),
#  ('85.74.197.75', '147.32.84.229'),
#  ('212.150.13.139', '147.32.85.56'),
#  ('137.226.22.200', '147.32.84.229'),
#  ('147.32.84.229', '188.243.224.246'),
#  ('147.32.84.229', '208.88.186.6'),
#  ('147.32.84.229', '140.113.241.72'),
#  ('86.122.180.15', '147.32.85.5'),
#  ('147.32.85.5', '86.122.180.15'),
#  ('113.161.76.167', '147.32.84.229'),
#  ('41.73.16.18', '147.32.84.229'),
#  ('80.243.105.201', '147.32.84.19'),
#  ('92.229.129.55', '147.32.84.229'),
#  ('218.174.104.27', '147.32.84.229'),
#  ('194.108.204.25', '147.32.84.130'),
#  ('122.234.239.181', '147.32.84.229'),
#  ('178.181.94.225', '147.32.84.229'),
#  ('116.118.72.167', '147.32.84.229'),
#  ('147.32.85.87', '74.125.232.200'),
#  ('46.49.40.197', '147.32.84.229'),
#  ('76.106.22.131', '147.32.84.229'),
#  ('80.137.117.141', '147.32.84.229'),
#  ('147.32.84.59', '74.125.39.125'),
#  ('147.32.86.164', '147.32.192.34'),
#  ('89.102.141.140', '147.32.84.229'),
#  ('93.195.100.144', '147.32.84.229'),
#  ('147.32.84.229', '120.126.145.55'),
#  ('147.32.84.229', '95.71.234.1'),
#  ('147.32.84.229', '70.162.43.190'),
#  ('147.32.84.229', '66.30.46.239'),
#  ('147.32.84.229', '192.251.226.205'),
#  ('95.42.237.123', '147.32.84.229'),
#  ('147.32.84.229', '119.77.174.243'),
#  ('147.32.84.229', '24.2.119.64'),
#  ('147.32.84.229', '190.190.194.237'),
#  ('147.32.84.229', '174.3.46.212'),
#  ('147.32.84.229', '68.44.195.26'),
#  ('147.32.84.229', '190.19.14.91'),
#  ('147.32.84.229', '201.173.72.116'),
#  ('147.32.84.229', '64.126.36.133'),
#  ('82.38.73.202', '147.32.84.229'),
#  ('213.150.1.132', '147.32.84.229'),
#  ('118.90.21.134', '147.32.84.229'),
#  ('81.0.215.241', '147.32.86.114'),
#  ('212.75.23.26', '147.32.84.229'),
#  ('31.40.21.62', '147.32.84.229'),
#  ('50.41.210.138', '147.32.84.229'),
#  ('151.41.174.231', '147.32.85.56'),
#  ('87.16.184.68', '147.32.84.229'),
#  ('147.32.84.229', '93.144.80.59'),
#  ('147.32.84.19', '147.32.80.9'),
#  ('84.123.149.59', '147.32.84.229'),
#  ('147.32.87.4', '147.32.86.164'),
#  ('147.32.87.1', '147.32.87.4'),
#  ('194.165.188.86', '147.32.84.229'),
#  ('220.181.94.226', '147.32.87.38'),
#  ('87.246.29.100', '147.32.84.229'),
#  ('194.154.73.182', '147.32.84.229'),
#  ('85.204.248.112', '147.32.84.229'),
#  ('63.64.124.138', '147.32.84.229'),
#  ('90.204.133.213', '147.32.84.229'),
#  ('41.132.207.74', '147.32.84.229'),
#  ('147.32.84.229', '68.2.37.70'),
#  ('147.32.84.229', '123.204.101.53'),
#  ('147.32.84.229', '213.169.39.184'),
#  ('202.153.42.146', '147.32.84.229'),
#  ('85.86.42.86', '147.32.84.229'),
#  ('117.9.59.6', '147.32.84.229'),
#  ('151.70.41.163', '147.32.84.229'),
#  ('147.32.86.111', '74.125.232.205'),
#  ('147.32.84.229', '78.141.179.7'),
#  ('212.232.32.222', '147.32.84.229'),
#  ('188.22.202.228', '147.32.84.229'),
#  ('147.32.85.5', '82.78.193.94'),
#  ('46.180.164.109', '147.32.84.229'),
#  ('210.22.139.70', '147.32.84.229'),
#  ('120.144.182.100', '147.32.84.229'),
#  ('147.32.89.183', '147.32.84.229'),
#  ('86.14.110.157', '147.32.84.229'),
#  ('222.152.253.133', '147.32.84.229'),
#  ('80.213.69.55', '147.32.84.229'),
#  ('64.13.156.166', '147.32.84.229'),
#  ('58.169.244.147', '147.32.84.229'),
#  ('121.220.224.115', '147.32.84.229'),
#  ('115.111.78.130', '147.32.84.229'),
#  ('147.32.85.87', '217.11.237.177'),
#  ('147.32.85.30', '66.220.151.74'),
#  ('88.102.153.171', '147.32.85.64'),
#  ('147.32.86.111', '74.125.232.223'),
#  ('87.121.129.35', '147.32.84.229'),
#  ('84.43.144.218', '147.32.84.229'),
#  ('49.50.201.80', '147.32.84.229'),
#  ('147.32.84.229', '147.52.43.94'),
#  ('147.32.84.229', '86.15.34.66'),
#  ('147.32.84.229', '147.231.251.19'),
#  ('92.63.50.180', '147.32.84.111'),
#  ('173.25.225.210', '147.32.84.229'),
#  ('62.233.166.26', '147.32.84.229'),
#  ('86.158.26.107', '147.32.84.229'),
#  ('87.207.187.182', '147.32.84.229'),
#  ('24.191.72.125', '147.32.84.229'),
#  ('147.32.85.89', '147.32.80.9'),
#  ('79.172.126.156', '147.32.84.229'),
#  ('98.150.77.62', '147.32.84.229'),
#  ('129.93.21.155', '147.32.84.229'),
#  ('151.55.55.208', '147.32.84.229'),
#  ('83.228.81.218', '147.32.84.229'),
#  ('213.211.63.102', '147.32.84.229'),
#  ('14.56.69.194', '147.32.84.229'),
#  ('90.154.252.3', '147.32.84.229'),
#  ('147.32.84.229', '24.177.245.141'),
#  ('147.32.84.229', '130.88.0.10'),
#  ('147.32.84.229', '77.8.35.140'),
#  ('147.32.84.229', '218.205.6.154'),
#  ('86.35.229.75', '147.32.84.229'),
#  ('139.168.192.65', '147.32.84.229'),
#  ('77.85.107.100', '147.32.84.229'),
#  ('202.65.168.73', '147.32.84.229'),
#  ('86.156.199.57', '147.32.84.229'),
#  ('74.125.232.245', '147.32.84.59'),
#  ('147.32.84.229', '77.220.1.242'),
#  ('71.173.175.240', '147.32.84.229'),
#  ('85.161.230.228', '147.32.84.242'),
#  ('58.215.221.66', '147.32.84.229'),
#  ('90.154.178.171', '147.32.84.229'),
#  ('147.32.86.111', '72.14.203.120'),
#  ('80.219.56.126', '147.32.84.229'),
#  ('147.32.162.206', '147.32.84.59'),
#  ('77.235.125.195', '147.32.84.229'),
#  ('147.32.84.59', '173.89.204.32'),
#  ('58.37.163.182', '147.32.84.229'),
#  ('80.153.122.36', '147.32.84.229'),
#  ('81.152.198.42', '147.32.84.229'),
#  ('136.148.70.16', '147.32.84.59'),
#  ('147.32.84.229', '64.126.89.161'),
#  ('75.205.65.98', '147.32.84.229'),
#  ('110.233.220.45', '147.32.84.229'),
#  ('217.15.123.90', '147.32.84.229'),
#  ('147.32.84.111', '212.185.174.100'),
#  ('83.148.88.40', '147.32.84.229'),
#  ('121.97.245.127', '147.32.84.229'),
#  ('86.136.196.105', '147.32.84.229'),
#  ('72.130.158.31', '147.32.84.229'),
#  ('60.179.101.28', '147.32.84.229'),
#  ('194.1.154.200', '147.32.84.229'),
#  ('118.93.230.161', '147.32.84.229'),
#  ('41.78.77.246', '147.32.84.229'),
#  ('147.32.84.229', '77.111.134.225'),
#  ('76.95.255.27', '147.32.84.229'),
#  ('147.32.84.227', '192.168.0.100'),
#  ('61.222.31.187', '147.32.84.229'),
#  ('147.32.84.229', '123.195.77.74'),
#  ('212.166.128.146', '147.32.84.229'),
#  ('62.103.28.174', '147.32.84.229'),
#  ('107.10.133.94', '147.32.84.229'),
#  ('151.66.167.254', '147.32.84.229'),
#  ('121.80.163.114', '147.32.84.229'),
#  ('195.238.88.2', '147.32.84.229'),
#  ('147.32.84.103', '111.221.96.179'),
#  ('81.151.7.18', '147.32.84.229'),
#  ('85.162.210.164', '147.32.86.184'),
#  ('88.163.106.228', '147.32.84.229'),
#  ('82.236.47.176', '147.32.84.229'),
#  ('121.222.36.193', '147.32.84.229'),
#  ('147.32.84.59', '2.21.98.110'),
#  ('64.13.156.169', '147.32.84.229'),
#  ('121.223.166.111', '147.32.84.229'),
#  ('68.65.164.42', '147.32.84.229'),
#  ('212.13.6.116', '147.32.84.229'),
#  ('157.157.224.2', '147.32.84.229'),
#  ('81.34.161.227', '147.32.84.229'),
#  ('147.32.84.229', '145.253.32.107'),
#  ('147.32.84.229', '187.66.3.97'),
#  ('93.142.137.131', '147.32.84.229'),
#  ('193.43.233.227', '147.32.84.229'),
#  ('111.251.98.241', '147.32.84.229'),
#  ('68.5.135.46', '147.32.84.229'),
#  ('89.134.56.174', '147.32.85.26'),
#  ('85.116.228.5', '147.32.84.229'),
#  ('147.32.84.229', '88.135.201.152'),
#  ('147.32.84.229', '46.137.52.146'),
#  ('147.32.84.229', '72.199.178.208'),
#  ('192.162.59.250', '147.32.84.229'),
#  ('208.88.186.7', '147.32.84.229'),
#  ('24.54.4.172', '147.32.84.229'),
#  ('121.96.155.109', '147.32.84.229'),
#  ('99.52.194.50', '147.32.84.229'),
#  ('134.219.116.11', '147.32.84.229'),
#  ('194.165.188.87', '147.32.84.229'),
#  ('74.125.232.215', '147.32.86.187'),
#  ('68.45.199.77', '147.32.84.229'),
#  ('78.251.119.140', '147.32.86.239'),
#  ('90.237.208.20', '147.32.84.229'),
#  ('123.231.10.34', '147.32.84.229'),
#  ('113.96.185.230', '147.32.84.229'),
#  ('213.168.161.119', '147.32.84.229'),
#  ('82.2.193.184', '147.32.84.229'),
#  ('209.169.101.205', '147.32.84.229'),
#  ('147.32.84.229', '94.169.59.209'),
#  ('147.32.84.59', '78.80.224.24'),
#  ('147.32.84.59', '91.204.156.67'),
#  ('147.32.84.59', '109.246.10.92'),
#  ('147.32.84.229', '71.92.5.135'),
#  ('147.32.84.229', '125.224.132.115'),
#  ('147.32.84.59', '92.122.213.24'),
#  ('95.55.163.196', '147.32.84.229'),
#  ('212.78.210.109', '147.32.84.229'),
#  ('147.32.84.229', '62.197.82.59'),
#  ('147.32.86.99', '69.63.190.10'),
#  ('147.32.86.99', '195.113.232.82'),
#  ('147.32.86.99', '195.113.232.74'),
#  ('147.32.86.99', '2.20.182.19'),
#  ('193.91.69.232', '147.32.86.172'),
#  ('147.32.86.172', '193.91.69.232'),
#  ('206.248.77.247', '147.32.84.229'),
#  ('147.32.86.99', '195.113.232.98'),
#  ('121.7.189.103', '147.32.84.229'),
#  ('94.99.67.116', '147.32.84.229'),
#  ('111.221.96.5', '147.32.84.103'),
#  ('203.82.80.95', '147.32.84.229'),
#  ('77.58.143.76', '147.32.84.229'),
#  ('213.243.66.250', '147.32.84.229'),
#  ('64.13.161.123', '147.32.84.229'),
#  ('41.104.37.150', '147.32.84.229'),
#  ('220.100.64.126', '147.32.84.229'),
#  ('147.32.84.229', '62.180.140.217'),
#  ('78.128.57.61', '147.32.84.229'),
#  ('147.32.86.99', '209.85.148.106'),
#  ('147.32.86.99', '74.125.232.218'),
#  ('147.32.86.99', '209.85.148.105'),
#  ('173.162.92.3', '147.32.84.229'),
#  ('62.218.20.3', '147.32.84.229'),
#  ('147.32.86.99', '88.86.101.2'),
#  ('147.32.84.59', '111.251.28.65'),
#  ('147.32.86.99', '68.67.179.209'),
#  ('147.32.84.229', '69.143.22.129'),
#  ('147.32.84.229', '142.217.0.82'),
#  ('147.32.84.229', '173.238.185.31'),
#  ('213.95.169.180', '147.32.84.229'),
#  ('79.45.250.17', '147.32.84.229'),
#  ('188.115.158.35', '147.32.84.229'),
#  ('109.152.83.188', '147.32.84.229'),
#  ('93.109.232.234', '147.32.84.229'),
#  ('212.166.128.122', '147.32.84.229'),
#  ('118.70.125.19', '147.32.84.229'),
#  ('90.154.206.125', '147.32.84.229'),
#  ('147.228.47.183', '147.32.86.190'),
#  ('79.206.170.254', '147.32.84.229'),
#  ('147.32.85.56', '78.102.90.206'),
#  ('147.32.84.229', '138.251.228.1'),
#  ('147.32.84.229', '151.25.39.209'),
#  ('147.32.84.229', '192.162.140.155'),
#  ('147.32.84.229', '151.65.252.195'),
#  ('147.32.84.229', '109.242.123.122'),
#  ...]

# %%
G = nx.Graph()
G.add_edges_from(edge_list)

# %%
class DeepWalk(object):
    def __init__(self, walk_length=5, window_size=2, n_walks=1, n_dim=2, learning_rate=0.01, decay_rate=1, verbose=False):
        self.walk_length = walk_length
        self.window_size = window_size
        self.n_walks = n_walks
        self.n_dim = n_dim
        self.learning_rate = learning_rate
        self.decay_rate = decay_rate
        self.verbose = verbose
        
    def fit(self, G):
        
        if not isinstance(G, nx.classes.graph.Graph):
            raise TypeError('G must be networkx Graph object.')
        
        A = nx.convert_matrix.to_numpy_array(G)
        self.__n = A.shape[0]
        
        # make sure A is symmetric
        if (A.sum(axis=1) != A.sum(axis=0)).any():
            raise ValueError('Graph must be undirected.')
        
        # calculate transition matrix P
        D = np.zeros(A.shape)
        d_diag = A.sum(axis=1)
        np.fill_diagonal(D, d_diag)
        P = np.linalg.inv(D) @ A
        
        # Initialized Random Weights
        self.W = np.random.rand(A.shape[0], self.n_dim)
        self.C = np.random.rand(A.shape[0], self.n_dim)
        self.W_orig = self.W
        self.C_orig = self.C
        self.loss_ = np.zeros(self.n_walks)
        prev_loss = np.inf
        for N in range(self.n_walks):
            self.loss = 0
            self.lr = self.learning_rate/(1 + self.decay_rate*N)
            walk = self.__generate_random_walk(A, P)

            # make contexts
            samples = self.__generate_contexts(walk)
            
            for w_t, w_c in samples:
                # forward pass
                y_pred, h, u = self.__forward_pass(w_t)
                
                # Calculate Error
                EI = np.sum([np.subtract(y_pred, context) for context in w_c], axis=0)
                
                # Backpropagate
                self.__backpropagate(EI, h, w_t)
        
                # calculate loss
                self.loss += -np.sum([u[list(context).index(True)] for context in w_c]) + len(w_c)*np.log(np.sum(np.exp(u)))
            self.loss_[N] = self.loss
            if self.verbose:
                print(f'Walk: {N} Loss: {self.loss}')
            
        return self
    
    def __generate_random_walk(self, A, P):
        
        walk = np.zeros(self.walk_length)
        node = np.random.choice(A.shape[0])
        walk[0] = node

        for i in range(1, self.walk_length):
            probs = P[node]
            node = np.random.choice(A.shape[0], p=probs)
            walk[i] = node
            
        return walk
    
    def __to_onehot(self, word):
        
        onehot = np.zeros(self.__n, dtype=bool)
        onehot[int(word)] = True
    
        return onehot
            
    def __generate_contexts(self, walk):
        sample = []
        for i in range(self.walk_length):
            center_word = self.__to_onehot(walk[i])
            contexts = []
            for j in range(i-self.window_size, i+self.window_size+1):
                if (j >= 0) and (i != j) and (j < self.walk_length):
                    contexts.append(self.__to_onehot(walk[j]))
            sample.append([center_word, contexts])
        return sample
        
    def __forward_pass(self, w):
        
        h = self.W.T @ w
        u = self.C @ h
        y_c = softmax(u)
        
        return y_c, h, u
    
    
    def __backpropagate(self, error, h, x):
        
        dL_dC = np.outer(error, h) # shape (n,d)
        dL_dW = np.outer(x, np.dot(self.C.T, error))
       
        self.W = self.W - self.lr*dL_dW
        self.C = self.C - self.lr*dL_dC

# %%
dw = DeepWalk(walk_length=100, window_size=5, n_walks=1000, n_dim=2, learning_rate=0.01, decay_rate=0.001, verbose=False).fit(G)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-8-5898ba90503a> in <module>
# ----> 1 dw = DeepWalk(walk_length=100, window_size=5, n_walks=1000, n_dim=2, learning_rate=0.01, decay_rate=0.001, verbose=False).fit(G)
#
# <ipython-input-7-34e75b15a063> in fit(self, G)
#      14             raise TypeError('G must be networkx Graph object.')
#      15
# ---> 16         A = nx.convert_matrix.to_numpy_array(G)
#      17         self.__n = A.shape[0]
#      18
#
# ~\anaconda3\lib\site-packages\networkx\convert_matrix.py in to_numpy_array(G, nodelist, dtype, order, multigraph_weight, weight, nonedge)
#    1135     else:
#    1136         # Graph or DiGraph, this is much faster than above
# -> 1137         A = np.full((nlen, nlen), np.nan, order=order)
#    1138         for u, nbrdict in G.adjacency():
#    1139             for v, d in nbrdict.items():
#
# ~\anaconda3\lib\site-packages\numpy\core\numeric.py in full(shape, fill_value, dtype, order)
#     323     if dtype is None:
#     324         dtype = array(fill_value).dtype
# --> 325     a = empty(shape, dtype, order)
#     326     multiarray.copyto(a, fill_value, casting='unsafe')
#     327     return a
#
# MemoryError: Unable to allocate 2.69 TiB for an array with shape (607565, 607565) and data type float64
